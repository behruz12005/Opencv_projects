# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2 as cv

# %%
img = cv.imread('/content/ras,.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FE528D81640>

# %%
# capture = cv.VideoCapture('/content/310336358_2360231147475802_6525962373777253472_n.mp4')
# while True:
#   isTrue,frame = capture.read()
#   if cv.waitKey(20) & 0xFF ==ord('d'):
#     break

# %%
def resclaeframe(frame,scale = 1):
  width = int(frame.shape[1] * scale)
  height = int(frame.shape[0] * scale)
  dimensions = (width,height)

  return cv.resize(frame, dimensions,interpolation = cv.INTER_AREA)

# %%
img2 = resclaeframe(img,scale = 1.15)
gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
gray = cv.cvtColor(img2,cv.COLOR_BGR2HSV)
gray = cv.cvtColor(img2,cv.COLOR_BGR2LAB)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=258x258 at 0x7FE53938B2B0>

# %%
blur = cv.GaussianBlur(img,(7,7),cv.BORDER_DEFAULT)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FE51EA04580>

# %%
canny = cv.Canny(img,125,175)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FE51EA04040>

# %%
canny = cv.Canny(img,125,175)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FE51EA040D0>

# %%
canny = cv.Canny(blur,125,175)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FE51EB54790>

# %%
croped = img[0:100,0:350]
cv2_imshow(croped)
# Out:
# <PIL.Image.Image image mode=RGB size=225x100 at 0x7FE51EA46700>

# %%
resize = cv.resize(img,(900,300),interpolation = cv.INTER_CUBIC)
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=900x300 at 0x7FE527F95D60>
